          "2014 Sep 01", "2014 Sep 10", "2015 Jun 21", "2017 Sep 06b"],
         ["2012 Mar 07", "2014 Feb 25",  "2017 Sep 10"]]

cos_c = [["2011 Mar 07", "2011 Sep 06", "2012 Jan 23", "2012 Jan 27", 
          "2012 Mar 05", "2012 Mar 07", "2012 May 17", "2013 Apr 11", 
          "2013 May 13b", "2013 Oct 11", "2014 Feb 25", "2014 Sep 01", 
          "2014 Sep 10", "2015 Jun 21", "2017 Sep 06b", "2017 Sep 10"],
         ["2011 Aug 09", "2012 Mar 09", "2013 May 13a"]]

euc_c = [["2011 Mar 07", "2011 Sep 06", "2012 Jan 27", "2012 Mar 05", 
          "2013 Apr 11", "2014 Feb 25", "2014 Sep 01", "2014 Sep 10", 
          "2015 Jun 21", "2017 Sep 06b", "2017 Sep 10"],
         ["2011 Aug 09", "2012 Mar 09", "2012 May 17", "2013 May 13a",
          "2013 May 13b", "2013 Oct 11"],
         ["2012 Jan 23", "2012 Mar 07"]]

methods = [PCA_e, cos_e, euc_e, PCA_d, cos_d, euc_d, PCA_r, cos_r, euc_r, PCA_c,
           cos_c, euc_c]

# %%
dic = {}
number = []
data = []



def restart(dictionnary, index) :
    for instance in index : 
        dictionnary[instance] = 0

for sf in sf_total :
    restart(dic, sf_total)
    n = 0
    occurence = []
    for m in methods : #on choisit la méthode
        for i in range(len(m)) : # i correspond à un groupe dans la méthode
            for j in range(len(m[i])) : # j correspond à un élément du groupe
                if sf == m[i][j] : 
                    n += 1
                    for sf2 in m[i] : 
                        dic[sf2] += 1      
    number.append(n) 
    for key, value in dic.items() : 
        occurence.append(value)
    data.append(occurence)

# %%
Mat = np.asmatrix(data)

pairing_exact = []
titre_exact = []
for i in range(len(sf_total)) : 
    for j in range(len(sf_total)) :
        if number[i] == Mat[j, i] and j < i :
            pairing_exact.append([Mat[j, i], j, i])
            titre_exact.append(str(sf_total[j]) + " ( " + str(number[j]) + " ) - " + str(sf_total[i]) + " ( " + str(number[i]) + " )")
            print(sf_total[j], "(", number[j], ") -", sf_total[i], "(", number[i], ") :", Mat[j, i])
# Out:
# 2011 Mar 07 ( 12 ) - 2012 Jan 27 ( 12 ) : 12
# 2011 Mar 07 ( 12 ) - 2013 May 14 ( 6 ) : 6
# 2012 Jan 27 ( 12 ) - 2013 May 14 ( 6 ) : 6
# 2011 Jun 07 ( 6 ) - 2013 May 15 ( 3 ) : 3
# 2013 Apr 11 ( 12 ) - 2013 May 15 ( 3 ) : 3
# 2013 May 13a ( 12 ) - 2013 May 15 ( 3 ) : 3
# 2011 Sep 06 ( 12 ) - 2013 Oct 25 ( 6 ) : 6
# 2011 Sep 24 ( 6 ) - 2014 Jun 10 ( 3 ) : 3
# 2013 May 13b ( 12 ) - 2014 Jun 10 ( 3 ) : 3
# 2011 Sep 06 ( 12 ) - 2014 Jun 11 ( 3 ) : 3
# 2013 Oct 25 ( 6 ) - 2014 Jun 11 ( 3 ) : 3
# 2014 Feb 25 ( 12 ) - 2017 Sep 10 ( 12 ) : 12

# %%
pairing = []
titre = []
for i in range(len(sf_total)) : 
    for j in range(len(sf_total)) :
        if number[i] - Mat[j, i] < 3 and j < i and Mat[j, i] > 4 :
            pairing.append([Mat[j, i], j, i])
            titre.append(str(sf_total[j]) + " ( " + str(number[j]) + " ) - " + str(sf_total[i]) + " ( " + str(number[i]) + " )")
            print(sf_total[j], "(", number[j], ") -", sf_total[i], "(", number[i], ") :", Mat[j, i])
# Out:
# 2011 Sep 06 ( 12 ) - 2011 Sep 07 ( 6 ) : 5
# 2011 Mar 07 ( 12 ) - 2012 Jan 27 ( 12 ) : 12
# 2012 Mar 05 ( 12 ) - 2012 Mar 10 ( 6 ) : 5
# 2011 Mar 07 ( 12 ) - 2013 May 14 ( 6 ) : 6
# 2012 Jan 27 ( 12 ) - 2013 May 14 ( 6 ) : 6
# 2012 May 17 ( 12 ) - 2013 May 14 ( 6 ) : 5
# 2013 Apr 11 ( 12 ) - 2013 Oct 11 ( 12 ) : 10
# 2013 May 13a ( 12 ) - 2013 Oct 11 ( 12 ) : 10
# 2011 Sep 06 ( 12 ) - 2013 Oct 25 ( 6 ) : 6
# 2011 Sep 07 ( 6 ) - 2013 Oct 25 ( 6 ) : 5
# 2011 Aug 04 ( 6 ) - 2014 Jan 06 ( 6 ) : 5
# 2012 Mar 07 ( 12 ) - 2014 Feb 25 ( 12 ) : 10
# 2013 Apr 11 ( 12 ) - 2014 Sep 01 ( 12 ) : 10
# 2012 Mar 05 ( 12 ) - 2015 Jun 21 ( 12 ) : 10
# 2011 Sep 06 ( 12 ) - 2017 Sep 06a ( 6 ) : 5
# 2011 Sep 07 ( 6 ) - 2017 Sep 06a ( 6 ) : 5
# 2013 Oct 25 ( 6 ) - 2017 Sep 06a ( 6 ) : 5
# 2012 Mar 07 ( 12 ) - 2017 Sep 10 ( 12 ) : 10
# 2014 Feb 25 ( 12 ) - 2017 Sep 10 ( 12 ) : 12

# %% [markdown]
# Associations en triplets et quadruplets

# %%
dic = {}
data = []
for liste in pairing_exact :
    restart(dic, sf_total)
    occurence = []
    for m in methods : #on choisit la méthode
        for i in range(len(m)) : # i correspond à un groupe dans la méthode
            if sf_total[liste[1]] in m[i] and sf_total[liste[2]] in m[i] :
                for sf2 in m[i] : 
                    dic[sf2] += 1      
    for key, value in dic.items() : 
        occurence.append(value)
    data.append(occurence)
    
Mat3X = np.asmatrix(data)

# %%
pairing_exact3 = []
titre_exact3 = []
for i in range(len(sf_total)) : 
    for j in range(len(pairing_exact)) :
        if pairing_exact[j][0] - Mat3X[j, i] < 3 and Mat3X[j, i] > 3 and i != pairing_exact[j][1] and i != pairing_exact[j][2] :
            pairing_exact3.append([Mat3X[j, i], j, i]) #[pairing_exact[1], pairing_exact[2], i]
            titre_exact3.append(titre_exact[j] + " - " + str(sf_total[i]) + " ( " + str(number[i]) + " )")
            print(titre_exact[j], "-", sf_total[i], "(", number[i], ") :", Mat3X[j, i])
# Out:
# 2012 Jan 27 ( 12 ) - 2013 May 14 ( 6 ) - 2011 Mar 07 ( 12 ) : 6
# 2011 Sep 06 ( 12 ) - 2013 Oct 25 ( 6 ) - 2011 Aug 04 ( 6 ) : 4
# 2011 Sep 06 ( 12 ) - 2013 Oct 25 ( 6 ) - 2011 Sep 07 ( 6 ) : 5
# 2011 Mar 07 ( 12 ) - 2013 May 14 ( 6 ) - 2012 Jan 23 ( 12 ) : 4
# 2012 Jan 27 ( 12 ) - 2013 May 14 ( 6 ) - 2012 Jan 23 ( 12 ) : 4
# 2011 Mar 07 ( 12 ) - 2013 May 14 ( 6 ) - 2012 Jan 27 ( 12 ) : 6
# 2014 Feb 25 ( 12 ) - 2017 Sep 10 ( 12 ) - 2012 Mar 07 ( 12 ) : 10
# 2011 Mar 07 ( 12 ) - 2013 May 14 ( 6 ) - 2012 May 17 ( 12 ) : 5
# 2012 Jan 27 ( 12 ) - 2013 May 14 ( 6 ) - 2012 May 17 ( 12 ) : 5
# 2011 Sep 06 ( 12 ) - 2013 Oct 25 ( 6 ) - 2014 Jan 06 ( 6 ) : 4
# 2011 Sep 06 ( 12 ) - 2013 Oct 25 ( 6 ) - 2017 Sep 06a ( 6 ) : 5

# %%
dic = {}
data = []
for liste in pairing :
    restart(dic, sf_total)
    occurence = []
    for m in methods : #on choisit la méthode
        for i in range(len(m)) : # i correspond à un groupe dans la méthode
            if sf_total[liste[1]] in m[i] and sf_total[liste[2]] in m[i] :
                for sf2 in m[i] : 
                    dic[sf2] += 1      
    for key, value in dic.items() : 
        occurence.append(value)
    data.append(occurence)
    
Mat3 = np.asmatrix(data)

# %%
pairing3 = []
titre3 = []
for i in range(len(sf_total)) : 
    for j in range(len(pairing)) :
        if pairing[j][0] - Mat3[j, i] < 3 and Mat3[j, i] > 4 and i != pairing[j][1] and i != pairing[j][2] :
            pairing3.append([Mat3[j, i], j, i])
            titre3.append(titre[j] + " - " + str(sf_total[i]) + " ( " + str(number[i]) + " )")
            print(titre[j], "-", sf_total[i], "(", number[i], ") :", Mat3[j, i])
# Out:
# 2012 Jan 27 ( 12 ) - 2013 May 14 ( 6 ) - 2011 Mar 07 ( 12 ) : 6
# 2012 May 17 ( 12 ) - 2013 May 14 ( 6 ) - 2011 Mar 07 ( 12 ) : 5
# 2012 Mar 05 ( 12 ) - 2015 Jun 21 ( 12 ) - 2011 Mar 07 ( 12 ) : 8
# 2011 Sep 07 ( 6 ) - 2013 Oct 25 ( 6 ) - 2011 Sep 06 ( 12 ) : 5
# 2011 Sep 07 ( 6 ) - 2017 Sep 06a ( 6 ) - 2011 Sep 06 ( 12 ) : 5
# 2013 Oct 25 ( 6 ) - 2017 Sep 06a ( 6 ) - 2011 Sep 06 ( 12 ) : 5
# 2011 Sep 06 ( 12 ) - 2013 Oct 25 ( 6 ) - 2011 Sep 07 ( 6 ) : 5
# 2011 Sep 06 ( 12 ) - 2017 Sep 06a ( 6 ) - 2011 Sep 07 ( 6 ) : 5
# 2013 Oct 25 ( 6 ) - 2017 Sep 06a ( 6 ) - 2011 Sep 07 ( 6 ) : 5
# 2011 Mar 07 ( 12 ) - 2013 May 14 ( 6 ) - 2012 Jan 27 ( 12 ) : 6
# 2012 May 17 ( 12 ) - 2013 May 14 ( 6 ) - 2012 Jan 27 ( 12 ) : 5
# 2012 Mar 05 ( 12 ) - 2015 Jun 21 ( 12 ) - 2012 Jan 27 ( 12 ) : 8
# 2014 Feb 25 ( 12 ) - 2017 Sep 10 ( 12 ) - 2012 Mar 07 ( 12 ) : 10
# 2011 Mar 07 ( 12 ) - 2013 May 14 ( 6 ) - 2012 May 17 ( 12 ) : 5
# 2012 Jan 27 ( 12 ) - 2013 May 14 ( 6 ) - 2012 May 17 ( 12 ) : 5
# 2013 May 13a ( 12 ) - 2013 Oct 11 ( 12 ) - 2013 Apr 11 ( 12 ) : 8
# 2013 Apr 11 ( 12 ) - 2013 Oct 11 ( 12 ) - 2013 May 13a ( 12 ) : 8
# 2013 Apr 11 ( 12 ) - 2014 Sep 01 ( 12 ) - 2013 Oct 11 ( 12 ) : 8
# 2011 Sep 06 ( 12 ) - 2011 Sep 07 ( 6 ) - 2013 Oct 25 ( 6 ) : 5
# 2011 Sep 06 ( 12 ) - 2017 Sep 06a ( 6 ) - 2013 Oct 25 ( 6 ) : 5
# 2011 Sep 07 ( 6 ) - 2017 Sep 06a ( 6 ) - 2013 Oct 25 ( 6 ) : 5
# 2012 Mar 07 ( 12 ) - 2017 Sep 10 ( 12 ) - 2014 Feb 25 ( 12 ) : 10
# 2013 Apr 11 ( 12 ) - 2013 Oct 11 ( 12 ) - 2014 Sep 01 ( 12 ) : 8
# 2013 Apr 11 ( 12 ) - 2014 Sep 01 ( 12 ) - 2014 Sep 10 ( 12 ) : 8
# 2012 Mar 05 ( 12 ) - 2015 Jun 21 ( 12 ) - 2014 Sep 10 ( 12 ) : 8
# 2012 Mar 05 ( 12 ) - 2012 Mar 10 ( 6 ) - 2015 Jun 21 ( 12 ) : 5
# 2011 Sep 06 ( 12 ) - 2011 Sep 07 ( 6 ) - 2017 Sep 06a ( 6 ) : 5
# 2011 Sep 06 ( 12 ) - 2013 Oct 25 ( 6 ) - 2017 Sep 06a ( 6 ) : 5
# 2011 Sep 07 ( 6 ) - 2013 Oct 25 ( 6 ) - 2017 Sep 06a ( 6 ) : 5
# 2012 Mar 07 ( 12 ) - 2014 Feb 25 ( 12 ) - 2017 Sep 10 ( 12 ) : 10

# %%
dic = {}
data = []
for liste in pairing_exact3 :
    restart(dic, sf_total)
    occurence = []
    for m in methods : #on choisit la méthode
        for i in range(len(m)) : # i correspond à un groupe dans la méthode
            if sf_total[liste[1]] in m[i] and sf_total[liste[2]] in m[i] :
                for sf2 in m[i] : 
                    dic[sf2] += 1      
    for key, value in dic.items() : 
        occurence.append(value)
    data.append(occurence)
    
Mat4X = np.asmatrix(data)

# %%
pairing_exact4 = []
titre_exact4 = []
for i in range(len(sf_total)) : 
    for j in range(len(pairing_exact3)) :
        p = pairing_exact3[j][1]
        paire = pairing_exact[p]
        if pairing_exact3[j][0] - Mat4X[j, i] < 3 and Mat4X[j, i] > 4 and i != paire[1] and i != paire[2] and i != pairing_exact3[j][2] :
            pairing_exact4.append([Mat4X[j, i], j, i])
            titre_exact4.append(titre_exact3[j] + " - " + str(sf_total[i]) + " ( " + str(number[i]) + " )")
            print(titre_exact3[j], "-", sf_total[i], "(", number[i], ") :", Mat4X[j, i])
            
if len(pairing_exact4) == 0 :
    print("Il n'y a pas de groupes de cette taille.")
# Out:
# Il n'y a pas de groupes de cette taille.

# %%
dic = {}
data = []
for liste in pairing3 :
    restart(dic, sf_total)
    occurence = []
    for m in methods : #on choisit la méthode
        for i in range(len(m)) : # i correspond à un groupe dans la méthode
            if sf_total[liste[1]] in m[i] and sf_total[liste[2]] in m[i] :
                for sf2 in m[i] : 
                    dic[sf2] += 1      
    for key, value in dic.items() : 
        occurence.append(value)
    data.append(occurence)
    
Mat4 = np.asmatrix(data)

# %%
pairing4 = []
titre4 = []
for i in range(len(sf_total)) : 
    for j in range(len(pairing3)) :
        p = pairing3[j][1]
        paire = pairing[p]
        if pairing3[j][0] - Mat4[j, i] < 3 and Mat4[j, i] > 4 and i != paire[1] and i != paire[2] and i != pairing3[j][2] :
            pairing4.append([Mat4[j, i], j, i])
            titre4.append(titre3[j] + " - " + str(sf_total[i]) + " ( " + str(number[i]) + " )")
            print(titre3[j], "-", sf_total[i], "(", number[i], ") :", Mat4[j, i])
            
if len(pairing4) == 0 :
    print("Il n'y a pas de groupes de cette taille.")
# Out:
# 2011 Sep 07 ( 6 ) - 2013 Oct 25 ( 6 ) - 2011 Sep 06 ( 12 ) - 2011 Mar 07 ( 12 ) : 6
# 2012 Mar 05 ( 12 ) - 2015 Jun 21 ( 12 ) - 2012 Jan 27 ( 12 ) - 2011 Mar 07 ( 12 ) : 9
# 2013 May 13a ( 12 ) - 2013 Oct 11 ( 12 ) - 2013 Apr 11 ( 12 ) - 2011 Mar 07 ( 12 ) : 6
# 2012 Jan 27 ( 12 ) - 2013 May 14 ( 6 ) - 2011 Mar 07 ( 12 ) - 2011 Sep 06 ( 12 ) : 6
# 2012 Mar 05 ( 12 ) - 2015 Jun 21 ( 12 ) - 2011 Mar 07 ( 12 ) - 2012 Jan 23 ( 12 ) : 8
# 2012 Mar 05 ( 12 ) - 2015 Jun 21 ( 12 ) - 2012 Jan 27 ( 12 ) - 2012 Jan 23 ( 12 ) : 8
# 2013 May 13a ( 12 ) - 2013 Oct 11 ( 12 ) - 2013 Apr 11 ( 12 ) - 2012 Jan 23 ( 12 ) : 6
# 2012 Mar 05 ( 12 ) - 2015 Jun 21 ( 12 ) - 2011 Mar 07 ( 12 ) - 2012 Jan 27 ( 12 ) : 9
# 2011 Sep 07 ( 6 ) - 2013 Oct 25 ( 6 ) - 2011 Sep 06 ( 12 ) - 2012 Jan 27 ( 12 ) : 6
# 2013 May 13a ( 12 ) - 2013 Oct 11 ( 12 ) - 2013 Apr 11 ( 12 ) - 2012 Jan 27 ( 12 ) : 6
# 2012 Jan 27 ( 12 ) - 2013 May 14 ( 6 ) - 2011 Mar 07 ( 12 ) - 2012 Mar 05 ( 12 ) : 6
# 2011 Sep 07 ( 6 ) - 2013 Oct 25 ( 6 ) - 2011 Sep 06 ( 12 ) - 2012 Mar 05 ( 12 ) : 6
# 2012 Mar 05 ( 12 ) - 2015 Jun 21 ( 12 ) - 2011 Mar 07 ( 12 ) - 2012 May 17 ( 12 ) : 9
# 2012 Mar 05 ( 12 ) - 2015 Jun 21 ( 12 ) - 2012 Jan 27 ( 12 ) - 2012 May 17 ( 12 ) : 9
# 2013 May 13a ( 12 ) - 2013 Oct 11 ( 12 ) - 2013 Apr 11 ( 12 ) - 2012 May 17 ( 12 ) : 6
# 2012 Jan 27 ( 12 ) - 2013 May 14 ( 6 ) - 2011 Mar 07 ( 12 ) - 2013 Apr 11 ( 12 ) : 6
# 2012 Mar 05 ( 12 ) - 2015 Jun 21 ( 12 ) - 2011 Mar 07 ( 12 ) - 2013 Apr 11 ( 12 ) : 6
# 2011 Sep 07 ( 6 ) - 2013 Oct 25 ( 6 ) - 2011 Sep 06 ( 12 ) - 2013 Apr 11 ( 12 ) : 6
# 2013 Oct 25 ( 6 ) - 2017 Sep 06a ( 6 ) - 2011 Sep 06 ( 12 ) - 2013 Apr 11 ( 12 ) : 6
# 2012 Mar 05 ( 12 ) - 2015 Jun 21 ( 12 ) - 2012 Jan 27 ( 12 ) - 2013 Apr 11 ( 12 ) : 6
# 2013 Oct 25 ( 6 ) - 2017 Sep 06a ( 6 ) - 2011 Sep 06 ( 12 ) - 2013 May 13b ( 12 ) : 7
# 2012 Mar 05 ( 12 ) - 2015 Jun 21 ( 12 ) - 2011 Mar 07 ( 12 ) - 2013 Oct 11 ( 12 ) : 6
# 2013 Oct 25 ( 6 ) - 2017 Sep 06a ( 6 ) - 2011 Sep 06 ( 12 ) - 2013 Oct 11 ( 12 ) : 6
# 2012 Mar 05 ( 12 ) - 2015 Jun 21 ( 12 ) - 2012 Jan 27 ( 12 ) - 2013 Oct 11 ( 12 ) : 6
# 2012 Jan 27 ( 12 ) - 2013 May 14 ( 6 ) - 2011 Mar 07 ( 12 ) - 2014 Sep 01 ( 12 ) : 6
# 2012 Mar 05 ( 12 ) - 2015 Jun 21 ( 12 ) - 2011 Mar 07 ( 12 ) - 2014 Sep 01 ( 12 ) : 6
# 2011 Sep 07 ( 6 ) - 2013 Oct 25 ( 6 ) - 2011 Sep 06 ( 12 ) - 2014 Sep 01 ( 12 ) : 6
# 2013 Oct 25 ( 6 ) - 2017 Sep 06a ( 6 ) - 2011 Sep 06 ( 12 ) - 2014 Sep 01 ( 12 ) : 6
# 2012 Mar 05 ( 12 ) - 2015 Jun 21 ( 12 
        -0.1503210609963594]

XX_r = [0.5854926890168801, 0, 0, -0.7915433339204386, -0.7940872478721503, 0, -1.126922510865148, 0.4952166004976435, 
        0.8427033578841723, -1.4843380365751377, 4.825284197982841, -1.4698266212222875, -1.1241724206826733, 
        -0.6837121339620831, -1.897292124348623, -1.4106178680488624, -0.241727390309594, 0, 0, -1.6955204708108123, 
        0, 0, 0, 0, 2.683324506451081, 0, 0, 0.23708152392791249, -1.275983967609539, -0.44813627054375954, -1.4936865072765029, 
        0, 1.794253141011223, 4.474210887275864]

YY_r = [-1.5049921227485672, 0, 0, 1.845388449775752, 1.4306254212566405, 0, 0.7783813667378476, -1.305353986741084, 
        -1.7142587832933367, -2.1160985301052597, -1.3647668397968544, -0.07625328472774254, -1.136597701500807, 
        -0.5650796751606373, 0.6172483864733909, 0.6773269378790918, 0.9578621998219123, 0, 0, 0.414739459361846, 
        0, 0, 0, 0, 2.754644031823554, 0, 0, 0.5418950226178022, -0.22232105105697494, -1.243439025741651, -0.10263631299608296, 
        0, 1.2335439911503927, 0.10014204697076474]

XX_c = [0.6139906792432268, 0, 0, -1.2177067339650482, -0.8887747683524788, 0, 0, -0.017238050215214094, 0.10071101717817176, 
        -2.026279070168666, 4.608916947534749, -1.8246011244762386, 0, -0.5163219746514598, -2.241717818161741, 
        -1.190209358993089, -0.6358448774144804, 0, 0, -1.56279651848261, 0, 0, 0, 0, 2.822579745985122, 0, 0, 
        0.17973571115528605, -1.330121420450441, -0.42452282556620136, 0, 0, 1.217181731294903, 4.333018708506208]

YY_c = [-1.2265920938107726, 0, 0, 1.4319693700458525, 1.5053422230059796, 0, 0, -1.4192201050731448, -2.120415054099944, 
        -2.2577263283440545, -1.2922211511584363, -0.15163894394583713, 0, -0.2762926726650963, 0.5135267885570574, 
        0.941664007790209, 0.6748282113583334, 0, 0, 0.6519024186161172, 0, 0, 0, 0, 2.670295427500448, 0, 0, 
        0.5631682841129901, -0.04392527713998655, -0.9067363938267641, 0, 0, 0.831822243436226, -0.08975095435917524]

coordX = [XX_e, XX_d, XX_r, XX_c]
coordY = [YY_e, YY_d, YY_r, YY_c]

# %%
PCA1 = []
PCA2 = []

for i in range(len(sf_total)) :
    distX = []
    distY = []
    for j in range(len(sf_total)) :
        dx = 0
        dy = 0
        for xx in coordX :
            n = 1
            essai = abs(xx[i] - xx[j])
            if essai != abs(xx[i]) and essai != abs(xx[j]) :
                dx += essai
                n += 1
        distX.append(dx / n) 
        
        for yy in coordY : 
            n = 1
            essai = abs(yy[i] - yy[j])
            if essai != abs(yy[i]) and essai != abs(yy[j]) :
                dy += essai
                n += 1
        distY.append(dy / n)
    PCA1.append(distX)
    PCA2.append(distY)
    
P1 = np.asmatrix(PCA1)
P2 = np.asmatrix(PCA2)

# %%
distance = []

for i in range(len(sf_total)) :
    dist = []
    for j in range(len(sf_total)) :
        x = float(P1[i, j])
        y = float(P2[i, j])
        d = np.sqrt(x*x + y*y)
        dist.append(d)
    distance.append(dist)
    
D = np.asmatrix(distance)

# %%
X2 = []
Y2 = []
D2 = []

for paire in pairing :
    a = paire[1]
    b = paire[2]
    X2.append(P1[a, b])
    Y2.append(P2[a, b])
    D2.append(D[a, b])

# %%
from pandas import qcut as cut
X2_color = cut(X2, 4, ("Très Proche", "Proche", "Distant", "Très Distant"))
Y2_color = cut(Y2, 4, ("Très Proche", "Proche", "Distant", "Très Distant"))
D2_color = cut(D2, 4, ("Très Proche", "Proche", "Distant", "Très Distant"))

a = 0
while a < len(pairing) :
    j = pairing[a][1]
    i = pairing[a][2]
    print(str(sf_total[j]) + " ( " + str(number[j]) + " ) - " + str(sf_total[i]) + " ( " + str(number[i]) + " )", 
          "-> PC1 :", X2_color[a], ", PC2 :", Y2_color[a], ", Distance générale :", D2_color[a])
    a += 1
# Out:
# 2011 Sep 06 ( 12 ) - 2011 Sep 07 ( 6 ) -> PC1 : Distant , PC2 : Proche , Distance générale : Proche
# 2011 Mar 07 ( 12 ) - 2012 Jan 27 ( 12 ) -> PC1 : Proche , PC2 : Proche , Distance générale : Proche
# 2012 Mar 05 ( 12 ) - 2012 Mar 10 ( 6 ) -> PC1 : Très Proche , PC2 : Très Distant , Distance générale : Distant
# 2011 Mar 07 ( 12 ) - 2013 May 14 ( 6 ) -> PC1 : Très Proche , PC2 : Distant , Distance générale : Proche
# 2012 Jan 27 ( 12 ) - 2013 May 14 ( 6 ) -> PC1 : Très Proche , PC2 : Distant , Distance générale : Proche
# 2012 May 17 ( 12 ) - 2013 May 14 ( 6 ) -> PC1 : Distant , PC2 : Distant , Distance générale : Distant
# 2013 Apr 11 ( 12 ) - 2013 Oct 11 ( 12 ) -> PC1 : Proche , PC2 : Très Proche , Distance générale : Très Proche
# 2013 May 13a ( 12 ) - 2013 Oct 11 ( 12 ) -> PC1 : Proche , PC2 : Proche , Distance générale : Très Proche
# 2011 Sep 06 ( 12 ) - 2013 Oct 25 ( 6 ) -> PC1 : Très Distant , PC2 : Distant , Distance générale : Distant
# 2011 Sep 07 ( 6 ) - 2013 Oct 25 ( 6 ) -> PC1 : Proche , PC2 : Très Proche , Distance générale : Très Proche
# 2011 Aug 04 ( 6 ) - 2014 Jan 06 ( 6 ) -> PC1 : Très Proche , PC2 : Proche , Distance générale : Très Proche
# 2012 Mar 07 ( 12 ) - 2014 Feb 25 ( 12 ) -> PC1 : Très Distant , PC2 : Très Distant , Distance générale : Très Distant
# 2013 Apr 11 ( 12 ) - 2014 Sep 01 ( 12 ) -> PC1 : Très Distant , PC2 : Très Proche , Distance générale : Très Distant
# 2012 Mar 05 ( 12 ) - 2015 Jun 21 ( 12 ) -> PC1 : Distant , PC2 : Très Distant , Distance générale : Très Distant
# 2011 Sep 06 ( 12 ) - 2017 Sep 06a ( 6 ) -> PC1 : Très Distant , PC2 : Proche , Distance générale : Très Distant
# 2011 Sep 07 ( 6 ) - 2017 Sep 06a ( 6 ) -> PC1 : Distant , PC2 : Très Proche , Distance générale : Proche
# 2013 Oct 25 ( 6 ) - 2017 Sep 06a ( 6 ) -> PC1 : Très Proche , PC2 : Très Proche , Distance générale : Très Proche
# 2012 Mar 07 ( 12 ) - 2017 Sep 10 ( 12 ) -> PC1 : Proche , PC2 : Très Distant , Distance générale : Distant
# 2014 Feb 25 ( 12 ) - 2017 Sep 10 ( 12 ) -> PC1 : Très Distant , PC2 : Très Distant , Distance générale : Très Distant
